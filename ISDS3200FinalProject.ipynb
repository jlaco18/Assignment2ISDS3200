# %%
#Importing packages and csv files

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

allunits=pd.read_csv("allunits_puf_21.csv")

occupied=pd.read_csv("occupied_puf_21.csv")

person=pd.read_csv("person_puf_21.csv")

vacant=pd.read_csv("vacant_puf_21.csv")

# %%
#The next four cells are deleting unneeded columns

df = pd.DataFrame(allunits)
for col in df.columns:
    if 'FW' in col:
        del df[col]

# %%
df2 = pd.DataFrame(occupied)
for col in df2.columns:
    if 'FW' in col:
        del df2[col]

# %%
df3 = pd.DataFrame(person)
for col in df3.columns:
    if 'PW' in col:
        del df3[col]

# %%
df4 = pd.DataFrame(vacant)
for col in df4.columns:
    if 'FW' in col:
        del df4[col]

# %%
#Editing the person dataframe to show necessary columns


df3 = df3[['CONTROL', 'LNO', 'RELATION_P', 'AGE_REC_P', 'GENDER_P', 'MARITALSTAT_P', 'MOVENYC_P', 'EDNOW_P', 'TOTAL_INC_REC_P']]

df3["RELATION_P"] = df3["RELATION_P"].replace({0: "Respondent", 
                                               1: "Husband or wife", 
                                               2: "Unmarried partner", 
                                               3: "Child", 
                                               4: "Brother or sister (stepbrother or stepsister)", 
                                               5: "Father or mother", 
                                               6: "Father-in-law or mother-in-law", 
                                               7: "Grandchild", 
                                               8: "Grandparent", 
                                               9: "Other relative (cousin, nephew, etc)", 
                                               10: "Roommate or broader", 
                                               11: "Other non-relative"})

df3["GENDER_P"] = df3["GENDER_P"].replace({1: "Male", 
                                           2: "Female",
                                           3: "Other"})

df3["MARITALSTAT_P"] = df3["MARITALSTAT_P"].replace({-2: "Not applicable (not the respondent)",
                                                     -1: "Not reported",
                                                     1: "Married",
                                                     2: "Divorced",
                                                     3: "Separated",
                                                     4: "Widowed",
                                                     5: "Never Married"})

df3["MOVENYC_P"] = df3["MOVENYC_P"].replace({-2: "Not applicable (born in the New York City)",
                                             -1: "Not reported",
                                             1954: "Moved in 1954 or earlier"})

df3["EDNOW_P"] = df3["EDNOW_P"].replace({-2: "Not applicable (under 5 years old or not in school or college in the last three months)",
                                         -1: "Not reported",
                                          1: "1st to 6th grade",
                                          2: "7th to 9th grade",
                                          3: "10th to 12th grade",
                                          4: "GED program"})

df3["TOTAL_INC_REC_P"] = df3["TOTAL_INC_REC_P"].replace({-2222222222: "Not applicable (under 15 years old)",
                                                         -40000000: "-$40,000,000 (net income loss)",
                                                         })




df3
# Out:
#         CONTROL  LNO                            RELATION_P  AGE_REC_P  \
# 0      12100003    1                            Respondent         64
# 1      12100005    1                            Respondent         88
# 2      12100008    1                            Respondent         48
# 3      12100008    2  Other relative (cousin, nephew, etc)         20
# 4      12100008    3                    Other non-relative         38
# ...         ...  ...                                   ...        ...
# 15580  12129988    3                                 Child         39
# 15581  12129999    1                            Respondent         27
# 15582  12129999    2                     Unmarried partner         28
# 15583  12130000    1                            Respondent         53
# 15584  12130001    1                            Respondent         42
#
#       GENDER_P                        MARITALSTAT_P  \
# 0       Female                        Never Married
# 1       Female                              Widowed
# 2         Male                        Never Married
# 3         Male  Not applicable (not the respondent)
# 4       Female  Not applicable (not the respondent)
# ...        ...                                  ...
# 15580     Male  Not applicable (not the respondent)
# 15581   Female                        Never Married
# 15582     Male  Not applicable (not the respondent)
# 15583   Female                            Separated
# 15584     Male                             Divorced
#
#                                         MOVENYC_P  \
# 0      Not applicable (born in the New York City)
# 1                                    Not reported
# 2                                            2016
# 3      Not applicable (born in the New York City)
# 4                                            2016
# ...                                           ...
# 15580                                        1987
# 15581                                        2018
# 15582                                        2020
# 15583  Not applicable (born in the New York City)
# 15584  Not applicable (born in the New York City)
#
#                                                  EDNOW_P TOTAL_INC_REC_P
# 0      Not applicable (under 5 years old or not in sc...            2000
# 1      Not applicable (under 5 years old or not in sc...            3696
# 2                                           Not reported           20160
# 3                                           Not reported           20120
# 4                                           Not reported               0
# ...                                                  ...             ...
# 15580  Not applicable (under 5 years old or not in sc...            1000
# 15581  Not applicable (under 5 years old or not in sc...           35000
# 15582  Not applicable (under 5 years old or not in sc...           65000
# 15583  Not applicable (under 5 years old or not in sc...            1950
# 15584  Not applicable (under 5 years old or not in sc...           32000
#
# [15585 rows x 9 columns]

# %%
#Editing the occupied dataframe to show necessary columns

df2 = df2[['CONTROL', 'TENURE', 'HHSIZE', 'HHDONEPLUS', 'MOD_HAVE', 'GRENT']]

df2["TENURE"] = df2["TENURE"].replace({1: "Renter", 
                                        2: "Owner"})
df2["HHDONEPLUS"] = df2["HHDONEPLUS"].replace({
                                       -1: "Not reported", 
                                        1: "One or more people has one or more disability measured in the NYCHVS",
                                        2: "No person has any disability measured in the NYCHVS"})
df2["MOD_HAVE"] = df2["MOD_HAVE"].replace({-2: "Not applicable (no one in household reported any difficulty)", 
                                           -1: "Not reported", 
                                            1: "Received a modification",
                                            2: "Did not receive a modification"})
mod_order = ["Received a modification"]
df2["GRENT"] = df2["GRENT"].replace({-2: 0,
                                     -1: 0})
df2
# Out:
#        CONTROL  TENURE  HHSIZE  \
# 0     12100003  Renter       1
# 1     12100005  Renter       1
# 2     12100008  Renter       6
# 3     12100010  Renter       3
# 4     12100013  Renter       4
# ...        ...     ...     ...
# 7084  12129984  Renter       2
# 7085  12129988  Renter       3
# 7086  12129999  Renter       2
# 7087  12130000  Renter       1
# 7088  12130001  Renter       1
#
#                                              HHDONEPLUS  \
# 0     One or more people has one or more disability ...
# 1     One or more people has one or more disability ...
# 2     No person has any disability measured in the N...
# 3     No person has any disability measured in the N...
# 4     No person has any disability measured in the N...
# ...                                                 ...
# 7084  One or more people has one or more disability ...
# 7085  No person has any disability measured in the N...
# 7086  No person has any disability measured in the N...
# 7087  No person has any disability measured in the N...
# 7088  No person has any disability measured in the N...
#
#                                                MOD_HAVE  GRENT
# 0                        Did not receive a modification    228
# 1                               Received a modification   1172
# 2     Not applicable (no one in household reported a...   2655
# 3     Not applicable (no one in household reported a...   1065
# 4     Not applicable (no one in household reported a...   1319
# ...                                                 ...    ...
# 7084                            Received a modification      0
# 7085  Not applicable (no one in household reported a...    909
# 7086  Not applicable (no one in household reported a...      0
# 7087  Not applicable (no one in household reported a...    400
# 7088  Not applicable (no one in household reported a...    778
#
# [7089 rows x 6 columns]

# %%
#Editing the vacant dataframe to show necessary columns

df4 = df4[['CONTROL', 'FIRSTOCC', 'REASON_NOTAVAIL', 'OWN', 'LASTRENT', 'VAC_LENGTH', 'ASKINGRENT', 'ASKINGPRICE']]


df4["FIRSTOCC"] = df4["FIRSTOCC"].replace({-1: "Not reported", 
                                            1: "First occupancy",
                                            2: "Previously occupied"})

df4["REASON_NOTAVAIL"] = df4["REASON_NOTAVAIL"].replace({-2: "Not Applicable (Unit Available for Rent and/or Sale)",
                                                         -1: "Not Reported",
                                                          1: "Rented or sold, not yet occupied",
                                                          2: "Awaiting or undergoing renovation",
                                                          3: "Held for occasional, seasonal, or recreational use",
                                                          4: "Additional reasons - one or more of the following: used or converted to non-residential use, in legal dispute, awaiting conversion or being converted to coop or condo, held pending sale of building, held for planned demolition, or owner’s personal problems",
                                                          5: "Held as vacant",
                                                          6: "Unit is dilapidated or otherwise uninhabitable",
                                                          7: "Held for other reasons",
                                                          8: "Two or more reasons reported"})
df4["OWN"] = df4["OWN"].replace({-2: "N/A",
                                 -1: "Not reported", 
                                  1: "Previous occupant was renter",
                                  2: "Previous occupant was owner"})

df4['LASTRENT'] = df4['LASTRENT'].replace({-2: 'N/A', -1: 'Not reported'})




df4["VAC_LENGTH"] = df4["VAC_LENGTH"].replace({-2: "N/A",
                                               -1: "Not Reported",
                                                1: "Less than one month",
                                                2: "1 to 2 months",
                                                3: "2 to 3 months",
                                                4: "3 to 6 months",
                                                5: "6 to 12 months",
                                                6: "12 months or longer"})

#The lines of code that have "_order" in them are used for ordering in the charts
vac_order = ["Less than one month", "1 to 2 months", "2 to 3 months", "3 to 6 months", "6 to 12 months", "12 months or longer"]

df4["ASKINGRENT"] = df4["ASKINGRENT"].replace({-2: "Not applicable (Unit is not available for rent)",
                                                1: "$1 to $1,499",
                                                2: "$1,500 to $2,299",
                                                3: "$2,300 to $3,099",
                                                4: "$3,100 to $3,899",
                                                5: "$3,900 or more"})

rent_order = ["$1 to $1,499", "$1,500 to $2,299", "$2,300 to $3,099", "$3,100 to $3,899", "$3,900 or more"]

df4["ASKINGPRICE"] = df4["ASKINGPRICE"].replace({-2: "Not applicable (not available for sale)",
                                                  1: "$1 to $299,999",
                                                  2: "$300,000 to $599,999",
                                                  3: "$600,000 to $899,999",
                                                  4: "$900,000 or more"})

price_order = ["$1 to $299,999", "$300,000 to $599,999", "$600,000 to $899,999", "$900,000 or more"]

df4
# Out:
#        CONTROL             FIRSTOCC  \
# 0     12100085  Previously occupied
# 1     12100093  Previously occupied
# 2     12100108  Previously occupied
# 3     12100132  Previously occupied
# 4     12100151  Previously occupied
# ...        ...                  ...
# 1300  12129932  Previously occupied
# 1301  12129945  Previously occupied
# 1302  12129967      First occupancy
# 1303  12129973  Previously occupied
# 1304  12129978      First occupancy
#
#                                         REASON_NOTAVAIL  \
# 0                     Awaiting or undergoing renovation
# 1                                        Held as vacant
# 2                          Two or more reasons reported
# 3                      Rented or sold, not yet occupied
# 4                          Two or more reasons reported
# ...                                                 ...
# 1300                   Rented or sold, not yet occupied
# 1301  Not Applicable (Unit Available for Rent and/or...
# 1302                       Two or more reasons reported
# 1303                  Awaiting or undergoing renovation
# 1304                       Two or more reasons reported
#
#                               OWN      LASTRENT           VAC_LENGTH  \
# 0     Previous occupant was owner  Not reported        2 to 3 months
# 1     Previous occupant was owner          1700  12 months or longer
# 2     Previous occupant was owner             0  12 months or longer
# 3                    Not reported           N/A         Not Reported
# 4     Previous occupant was owner           550  12 months or longer
# ...                           ...           ...                  ...
# 1300  Previous occupant was owner             0  Less than one month
# 1301  Previous occupant was owner  Not reported        1 to 2 months
# 1302                          N/A           N/A  12 months or longer
# 1303  Previous occupant was owner  Not reported        3 to 6 months
# 1304                          N/A           N/A  12 months or longer
#
#                                            ASKINGRENT  \
# 0     Not applicable (Unit is not available for rent)
# 1                                    $1,500 to $2,299
# 2     Not applicable (Unit is not available for rent)
# 3     Not applicable (Unit is not available for rent)
# 4     Not applicable (Unit is not available for rent)
# ...                                               ...
# 1300  Not applicable (Unit is not available for rent)
# 1301                                   $3,900 or more
# 1302  Not applicable (Unit is not available for rent)
# 1303  Not applicable (Unit is not available for rent)
# 1304  Not applicable (Unit is not available for rent)
#
#                                   ASKINGPRICE
# 0     Not applicable (not available for sale)
# 1     Not applicable (not available for sale)
# 2     Not applicable (not available for sale)
# 3     Not applicable (not available for sale)
# 4     Not applicable (not available for sale)
# ...                                       ...
# 1300  Not applicable (not available for sale)
# 1301  Not applicable (not available for sale)
# 1302  Not applicable (not available for sale)
# 1303  Not applicable (not available for sale)
# 1304  Not applicable (not available for sale)
#
# [1305 rows x 8 columns]

# %%
#This chart shows the distribution of asking rent

filtered_df4_rent = df4[df4['ASKINGRENT'] != "Not applicable (Unit is not available for rent)"]
sns.countplot(data=filtered_df4_rent, x='ASKINGRENT', order=rent_order)
plt.xlabel('Asking Rent')
plt.ylabel('Count')
plt.title('Distribution of Asking Rent')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
#This chart shows the distribution of rent for those who have had modifications made to their living space

filtered_df2 = df2[df2["MOD_HAVE"].isin(mod_order)]
filtered_df2 = filtered_df2[filtered_df2["GRENT"] != 0]
ax = sns.swarmplot(data=filtered_df2, x="GRENT", y="MOD_HAVE")
ax.set(ylabel="")
# Out:
# C:\Users\lacou\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0.5, '')]

# %%
#This chart compares the length of vacancy to the asking rent of a living space

df4['VAC_LENGTH'] = pd.Categorical(df4['VAC_LENGTH'], categories=vac_order, ordered=True)
ByVacLength = df4.groupby('VAC_LENGTH').count()
ByVacLength['ASKINGRENT'].plot()

plt.xticks(rotation=90)

plt.title('Comparing Vacancy Length and Asking Rent')

plt.xlabel('Vacany Length')

plt.ylabel('Asking Rent')
# Out:
# Text(0, 0.5, 'Asking Rent')

# %%
#Merging the dataframes to compare attributes from different dataframes

merged_df = pd.merge(df3, df2, on ='CONTROL', how ='inner')

# %%
#After merging the datasets, this chart shows the correlation between the age of a person renting and the cost of renting

merged_subset1 = merged_df[['AGE_REC_P', 'GRENT']].head(45)
merged_subset1 = merged_subset1.sort_values(by=['AGE_REC_P', 'GRENT'])


plt.scatter(merged_subset1['AGE_REC_P'], merged_subset1['GRENT'])
plt.xlabel('Age')
plt.ylabel('Rent')
plt.title('Scatter Plot: Age vs Rent')
plt.show()
